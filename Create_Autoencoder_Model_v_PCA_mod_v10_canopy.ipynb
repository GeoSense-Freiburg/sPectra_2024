# %% [markdown]
# # Variational Autoencoder v PCA

# %% [markdown]
# In this notebook I want to show two types of dimensionality reduction for tabular data: PCA and Autoencoders.

# %% [markdown]
# I use the [wine dataset](https://archive.ics.uci.edu/ml/datasets/wine) to show how Variational Autoencoder (VAE) with PyTorch on tabular data works and compare it to the classic PCA approach. I use the PCA/VAE to reduce the dimensionality of dataset, in this case don to 3 Variables (embeddings). I then plot the embeddings in a 3D graph to show how VAE is similar to a PCA but works in a non-linear way.

# %% [markdown]
# ## TODO

# %% [markdown]
# * safe model
# * safe latent space

# %% [markdown]
# # Imports

# %%
# ! pip install rioxarray rasterio wandb

# %%
# mamba create -n sdiv_spectra python=3.10
# mamba init
# mamba activate sdiv_spectra
# mamba install pytorch matplotlib scikit-learn pandas -c conda-forge

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import nn, optim
from torch.autograd import Variable
from sklearn.decomposition import PCA

import pandas as pd
import numpy as np
from sklearn import preprocessing

import matplotlib.pyplot as plt
import os
import csv
import random
from scipy.signal import savgol_filter
import rioxarray
import glob
import geopandas as gpd
import rasterio
import wandb

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
# path to dataset
data_path = '/mnt/gsdata/users/kattenborn/data/sdiv_spectra/canopy_data/DB_47_Meta_EC_with_locations.csv'
folder_path = os.path.dirname(data_path)
#data_path = 'G:/My Drive/projects/project_sPectra/DB_47_Meta_EC.csv'

# path for model output
model_out_dir = '/mnt/gsdata/users/kattenborn/data/sdiv_spectra/dimred_canopy_v10_10lv/'
# check if model output directory exists and create it if not
if not os.path.exists(model_out_dir):
   os.makedirs(model_out_dir)


# # path to dataset
# data_path = '/content/drive/MyDrive/spectra_db/DB_47_Meta_EC.csv'
# #data_path = 'G:/My Drive/projects/project_sPectra/DB_47_Meta_EC.csv'

# # path for model output
# model_out_dir = '/content/drive/MyDrive/spectra_db/sdiv_spectra/dimred_canopy_v6/'
# # check if model output directory exists and create it if not
# if not os.path.exists(model_out_dir):
#     os.makedirs(model_out_dir)

# %% [markdown]
# # Load Dataset & preprocessing

# %%
df = pd.read_csv(data_path, sep=',')
df
# Out:
# /tmp/ipykernel_3220047/3788649274.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path, sep=',')
#       Unnamed: 0              Species  dataset  numSamples  LandCover  \
# 0              0          Agrostis sp        1          73  Grassland
# 1              1          Agrostis sp        1          73  Grassland
# 2              2          Agrostis sp        1          73  Grassland
# 3              3          Agrostis sp        1          73  Grassland
# 4              4  Angelica sylvestris        1          73  Grassland
# ...          ...                  ...      ...         ...        ...
# 5878        5878    Fagus grandifolia       47         166        NaN
# 5879        5879  Populus tremuloides       47         166        NaN
# 5880        5880  Populus tremuloides       47         166        NaN
# 5881        5881  Populus tremuloides       47         166        NaN
# 5882        5882    Fagus grandifolia       47         166        NaN
#
#           Tool                  Sensor                Site    Year  \
# 0     Proximal         ASD FieldSpec 3     BattSP, Belgium  2016.0
# 1     Proximal           SVC HR-1024TM   DeMatCem, Belgium  2016.0
# 2     Proximal           SVC HR-1024TM  HaachtBev, Belgium  2016.0
# 3     Proximal         ASD FieldSpec 3  HaachtHol, Belgium  2016.0
# 4     Proximal           SVC HR-1024TM  HaachtBev, Belgium  2016.0
# ...        ...                     ...                 ...     ...
# 5878  Airborne  CASI-1500 and SASI-805                 NaN  2022.0
# 5879  Airborne  CASI-1500 and SASI-806                 NaN  2022.0
# 5880  Airborne  CASI-1500 and SASI-807                 NaN  2022.0
# 5881  Airborne  CASI-1500 and SASI-808                 NaN  2022.0
# 5882  Airborne  CASI-1500 and SASI-809                 NaN  2022.0
#
#       Al_area_mg_cm2  ...          2493          2494          2495  \
# 0                NaN  ... -5.100964e-01 -4.273743e-01 -3.817722e-01
# 1                NaN  ... -1.440324e-01 -2.166700e-01 -1.766549e-01
# 2                NaN  ... -1.035611e-01 -3.517213e-02  5.051771e-02
# 3                NaN  ...  2.704971e-01  5.217226e-02 -4.300934e-01
# 4                NaN  ...  7.792805e-02  1.069778e-01  8.317470e-02
# ...              ...  ...           ...           ...           ...
# 5878             NaN  ...  1.575385e-02  1.575385e-02  1.575385e-02
# 5879             NaN  ...  1.100000e-19  1.100000e-19  1.100000e-19
# 5880             NaN  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 5881             NaN  ...  2.297500e-02  2.297500e-02  2.297500e-02
# 5882             NaN  ...  0.000000e+00  0.000000e+00  0.000000e+00
#
#               2496          2497          2498          2499          2500  \
# 0    -3.606211e-01 -3.365253e-01 -2.537969e-01 -1.047274e-01 -8.562174e-02
# 1    -1.124554e-01 -4.854697e-02  7.510346e-03  3.710629e-02  3.651872e-02
# 2     1.400784e-01  1.920989e-01  2.155951e-01  2.117149e-01  1.619342e-01
# 3    -3.218315e-01 -2.314438e-01 -2.337150e-01 -5.511845e-02 -6.315379e-03
# 4     5.113662e-02  4.280231e-02  4.788594e-02  4.579319e-02  3.343637e-02
# ...            ...           ...           ...           ...           ...
# 5878  1.575385e-02  1.575385e-02  1.575385e-02  1.575385e-02  1.575385e-02
# 5879  1.100000e-19  1.100000e-19  1.100000e-19  1.100000e-19  1.100000e-19
# 5880  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 5881  2.297500e-02  2.297500e-02  2.297500e-02  2.297500e-02  2.297500e-02
# 5882  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#        Latitude  Longitude
# 0     51.050452   4.432147
# 1     50.953734   5.436023
# 2     50.978703   4.608445
# 3     50.984960   4.589217
# 4     50.978703   4.608445
# ...         ...        ...
# 5878  45.993620 -74.005580
# 5879  45.993740 -74.003370
# 5880  45.993540 -74.005370
# 5881  45.989730 -74.002950
# 5882  45.992690 -74.000940
#
# [5883 rows x 2167 columns]

# %% [markdown]
# ## Add soil and climate data

# %% [markdown]
# ### Prepare worldclim

# %%
# query files
clim_files = glob.glob('/mnt/gsdata/users/kattenborn/data/sdiv_spectra/earth_obseration_products/worldclim_res/**/*.tif', recursive=True)

# open all files
clim = {os.path.basename(rf).split('deg_', 1)[-1].split('.tif', 1)[0]: rioxarray.open_rasterio(rf) for rf in clim_files}
clim.keys()
# Out:
# dict_keys(['bio_1', 'bio_12', 'bio_13-14', 'bio_15', 'bio_4', 'bio_7'])

# %%
# set all no data and inf vlaues to nan
clim["bio_1"].rio.write_nodata(3.400000e+38, inplace=True)
clim = {key: raster.where((raster > -3.400000e+37) & (raster < 3.400000e+37) & (raster != -np.inf), other=np.nan) for key, raster in clim.items()}
# Out:
# /home/tk1112/miniconda3/envs/sdiv_spectra/lib/python3.10/site-packages/rioxarray/raster_writer.py:130: UserWarning: The nodata value (3.4e+38) has been automatically changed to (3.3999999521443642e+38) to match the dtype of the data.
#   warnings.warn(

# %% [markdown]
# ### Prepare soilgrids

# %%
# query files
soil_files = glob.glob('/mnt/gsdata/users/kattenborn/data/sdiv_spectra/earth_obseration_products/soil_res/**/*.tif', recursive=True)

# filter keys to include any sand, soil but always 15-30cm
keywords = ["sand", "clay", "soc", "nitrogen"]
soil_files = [f for f in soil_files if any(word in f for word in keywords) and "15-30cm" in f]

# open all files
soil = {os.path.basename(rf).split('deg_', 1)[-1].split('.tif', 1)[0]: rioxarray.open_rasterio(rf) for rf in soil_files}
soil.keys()
# Out:
# dict_keys(['clay_15-30cm_mean_0.01_deg', 'nitrogen_15-30cm_mean_0.01_deg', 'sand_15-30cm_mean_0.01_deg', 'soc_15-30cm_mean_0.01_deg'])

# %%
# browse through the layers of the soil rasterstack and set all values with -32768 to nan
soil = {key: raster.where((raster > -32768) & (raster != -np.inf), other=np.nan) for key, raster in soil.items()}

# %%
# replace empty cells in df['Longitude'] and df['Latitude'] with -25.3556 and -14.5704
df['Longitude'].fillna(-25.3556, inplace=True)
df['Latitude'].fillna(-14.5704, inplace=True)
# Out:
# /tmp/ipykernel_3220047/3753790217.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Longitude'].fillna(-25.3556, inplace=True)
# /tmp/ipykernel_3220047/3753790217.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Latitude'].fillna(-14.5704, inplace=True)

# %%
# convert the sPlot data frame to a GeoDataFrame using geopandas (so we can extract the predictor values for each sPlot data point)
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))

# %%
# how many x coordiantes in gdf.geometry.x are empty?
print(gdf.geometry.x.isna().sum())
# Out:
# 0

# %%
# extract the pixel information at each sPlotOpen plot location
clim_extr = pd.DataFrame()
os.makedirs("temp", exist_ok=True)

for layer in clim.keys():
    clim[layer].rio.to_raster("temp/temp_raster.tif")
    with rasterio.open("temp/temp_raster.tif") as src:
        # only extract for non-empty geometries
        coords = [(x.x, x.y) for x in gdf.geometry]
        values = list(src.sample(coords))
        values = np.asarray(values)
        clim_extr[layer] = pd.DataFrame(values, columns=[layer])

# %%
# extract the soil pixel value at each gdf location (lat, long)
soil_extr = pd.DataFrame()
os.makedirs("temp", exist_ok=True)

for layer in soil.keys():
    soil[layer].rio.to_raster("temp/temp_raster.tif")
    with rasterio.open("temp/temp_raster.tif") as src:
        coords = [(x.x, x.y) for x in gdf.geometry]
        values = list(src.sample(coords))
        values = np.asarray(values)
        soil_extr[layer] = pd.DataFrame(values, columns=[layer])

# %%
# append the exracts to the df
df = pd.concat([df, clim_extr, soil_extr], axis=1)
df
# Out:
#       Unnamed: 0              Species  dataset  numSamples  LandCover  \
# 0              0          Agrostis sp        1          73  Grassland
# 1              1          Agrostis sp        1          73  Grassland
# 2              2          Agrostis sp        1          73  Grassland
# 3              3          Agrostis sp        1          73  Grassland
# 4              4  Angelica sylvestris        1          73  Grassland
# ...          ...                  ...      ...         ...        ...
# 5878        5878    Fagus grandifolia       47         166        NaN
# 5879        5879  Populus tremuloides       47         166        NaN
# 5880        5880  Populus tremuloides       47         166        NaN
# 5881        5881  Populus tremuloides       47         166        NaN
# 5882        5882    Fagus grandifolia       47         166        NaN
#
#           Tool                  Sensor                Site    Year  \
# 0     Proximal         ASD FieldSpec 3     BattSP, Belgium  2016.0
# 1     Proximal           SVC HR-1024TM   DeMatCem, Belgium  2016.0
# 2     Proximal           SVC HR-1024TM  HaachtBev, Belgium  2016.0
# 3     Proximal         ASD FieldSpec 3  HaachtHol, Belgium  2016.0
# 4     Proximal           SVC HR-1024TM  HaachtBev, Belgium  2016.0
# ...        ...                     ...                 ...     ...
# 5878  Airborne  CASI-1500 and SASI-805                 NaN  2022.0
# 5879  Airborne  CASI-1500 and SASI-806                 NaN  2022.0
# 5880  Airborne  CASI-1500 and SASI-807                 NaN  2022.0
# 5881  Airborne  CASI-1500 and SASI-808                 NaN  2022.0
# 5882  Airborne  CASI-1500 and SASI-809                 NaN  2022.0
#
#       Al_area_mg_cm2  ...      bio_1       bio_12  bio_13-14     bio_15  \
# 0                NaN  ...  10.275092   780.937805  25.266666  12.621699
# 1                NaN  ...  10.163222   768.791138  26.782223  13.121497
# 2                NaN  ...  10.507500   762.364441  24.244444  11.929838
# 3                NaN  ...  10.289963   787.431091  23.120001  11.446590
# 4                NaN  ...  10.507500   762.364441  24.244444  11.929838
# ...              ...  ...        ...          ...        ...        ...
# 5878             NaN  ...   4.520259  1097.742188  39.555557  13.416389
# 5879             NaN  ...   4.520259  1097.742188  39.555557  13.416389
# 5880             NaN  ...   4.520259  1097.742188  39.555557  13.416389
# 5881             NaN  ...   4.520259  1097.742188  39.555557  13.416389
# 5882             NaN  ...   4.520259  1097.742188  39.555557  13.416389
#
#             bio_4      bio_7  clay_15-30cm_mean_0.01_deg  \
# 0      546.305664  22.200001                         NaN
# 1      573.767578  23.498667                       215.0
# 2      563.066711  22.489779                         NaN
# 3      551.492249  22.370667                       231.0
# 4      563.066711  22.489779                         NaN
# ...           ...        ...                         ...
# 5878  1156.987671  42.781334                       123.0
# 5879  1156.987671  42.781334                       123.0
# 5880  1156.987671  42.781334                       123.0
# 5881  1156.987671  42.781334                       123.0
# 5882  1156.987671  42.781334                       123.0
#
#       nitrogen_15-30cm_mean_0.01_deg  sand_15-30cm_mean_0.01_deg  \
# 0                                NaN                         NaN
# 1                              144.0                       230.0
# 2                                NaN                         NaN
# 3                              264.0                       404.0
# 4                                NaN                         NaN
# ...                              ...                         ...
# 5878                           197.0                       497.0
# 5879                           197.0                       497.0
# 5880                           197.0                       497.0
# 5881                           197.0                       497.0
# 5882                           197.0                       497.0
#
#       soc_15-30cm_mean_0.01_deg
# 0                           NaN
# 1                         139.0
# 2                           NaN
# 3                         177.0
# 4                           NaN
# ...                         ...
# 5878                      320.0
# 5879                      320.0
# 5880                      320.0
# 5881                      320.0
# 5882                      320.0
#
# [5883 rows x 2177 columns]

# %%
# write df to a file
df.to_csv(os.path.join(folder_path, 'mergeddata_canopy.csv'), index=False)
# define the new data path accordingly
data_path = os.path.join(folder_path, 'mergeddata_canopy.csv')

# %%
layer = "bio_15"

# overlay the raster with the points
plt.figure(figsize=(15, 6)) # Set the figure size
clim[layer].plot(vmin=clim[layer].quantile(0.05), vmax=clim[layer].quantile(0.95))
gdf.plot(ax=plt.gca(), color='r', markersize=2)
plt.show()

# %% [markdown]
# ## Data loading function

# %%
def golay_spectra(df_base):
  db_copy = df_base.copy()
  # Apply Savitzky Golay filter to separate regions (to avoid smoothing in overly noisy regions)
  db_copy.loc[:,  '400':'1350'] = df_base.loc[:, '400':'1350'].apply(lambda row: savgol_filter(row, window_length=45, polyorder=1), axis=1).to_list()
  db_copy.loc[:, '1430':'1801'] = df_base.loc[:, '1430':'1801'].apply(lambda row: savgol_filter(row, window_length=45, polyorder=1), axis=1).to_list()
  db_copy.loc[:, '2050':'2500'] = df_base.loc[:, '2050':'2500'].apply(lambda row: savgol_filter(row, window_length=45, polyorder=1), axis=1).to_list()
  return db_copy

# %%
def load_data(path):
    # read in from csv
    df = pd.read_csv(path, sep=',', low_memory=False)

    #### spectra processing ###
    wv = ['{}'.format(i) for i in range(400,2501)]
    df_base = df.loc[:, wv]

    ### eliminate negative and high values in the spectra ##
    other = df_base.copy()
    # other.columns = other.columns.astype('int')
    other[other<0] = np.nan
    #####Substitute high values with the mean of neighbour values
    other[other>1] = np.nan
    ### interpolate the nan values ###
    other = (other.ffill() + other.bfill())/2
    other = other.interpolate(method='linear',limit_area=None, axis=1, limit_direction='both')
    ### golay filter ##
    df_base = golay_spectra(other)
    # df_base.columns = wv

    # set values in the columns 400-410, 1351–1430, 1801–2050 and 2451–2501 to 0
    df_base.loc[:, '400':'410'] = 0
    df_base.loc[:, '1351':'1430'] = 0
    df_base.loc[:, '1801':'2050'] = 0
    df_base.loc[:, '2451':'2500'] = 0

    df_meta = df.drop(wv, axis=1) #df.iloc[:,metaindex]#.values
    x = df_base.values.reshape(-1, df_base.shape[1]).astype('float32')

    # standardize values
    standardizer = preprocessing.StandardScaler()
    x = standardizer.fit_transform(x)
    return x, standardizer , df_meta

# %% [markdown]
# # Dimension reduction via principal component analysis (PCA)

# %%
x, standardizer, df_meta = load_data(data_path)

# %%
# calculate PCA
n_comp = 10
pca = PCA(n_components=n_comp)
principalComponents = pca.fit_transform(x)
columns = ['principal component ' + str(i+1) for i in range(n_comp)]
principalDf = pd.DataFrame(data = principalComponents, columns = columns)

# %%
# calculate explained variance and plot it
explained_variance = pca.explained_variance_ratio_ * 100
print('expl. variance per PC:', explained_variance)
print('cumulative expl. variance:', sum(explained_variance))
# Out:
# expl. variance per PC: [56.85427    32.055107    4.9374776   1.6035786   1.2657688   1.022965
#   0.56075835  0.4008662   0.31177256  0.20475858]
# cumulative expl. variance: 99.2173236310482

# %%
# barplot of explained variance of the first 10 components (plot components as integer)
components = [str(i+1) for i in range(10)]
plt.bar(components, explained_variance)
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance (%)')
plt.title('Explained Variance of the Principal Components')
plt.show()

# %%
finalDf = pd.concat([principalDf, pd.DataFrame(df_meta)], axis = 1)

# %%
finalDf.head()
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0              -4.636744             -15.965227              -3.943038
# 1              21.166925               4.270346              -7.578181
# 2              25.718765             -22.794184              -9.769650
# 3              -9.279778             -16.018137              -9.674307
# 4              -5.690102              -9.028572               4.543770
#
#    principal component 4  principal component 5  principal component 6  \
# 0              -2.358260              -2.910763              -7.070444
# 1              -3.830983              -0.649372              -1.907330
# 2               2.046790              -0.666760              -7.874128
# 3              -3.819446              -3.397510              -4.119681
# 4              -7.430706               2.394034              -2.786131
#
#    principal component 7  principal component 8  principal component 9  \
# 0               3.658725              -6.957286              -2.183586
# 1               3.754786              -3.985533              -0.438371
# 2               4.428617              -4.230455              -2.846822
# 3               1.548651              -3.977790               0.272819
# 4               2.459482              -4.772718              -1.252554
#
#    principal component 10  ...      bio_1     bio_12  bio_13-14     bio_15  \
# 0                1.663443  ...  10.275092  780.93780  25.266666  12.621699
# 1                3.282870  ...  10.163222  768.79114  26.782223  13.121497
# 2                3.966171  ...  10.507500  762.36444  24.244444  11.929838
# 3                0.904406  ...  10.289963  787.43110  23.120000  11.446590
# 4                2.550126  ...  10.507500  762.36444  24.244444  11.929838
#
#        bio_4      bio_7 clay_15-30cm_mean_0.01_deg  \
# 0  546.30566  22.200000                        NaN
# 1  573.76760  23.498667                      215.0
# 2  563.06670  22.489779                        NaN
# 3  551.49225  22.370667                      231.0
# 4  563.06670  22.489779                        NaN
#
#   nitrogen_15-30cm_mean_0.01_deg  sand_15-30cm_mean_0.01_deg  \
# 0                            NaN                         NaN
# 1                          144.0                       230.0
# 2                            NaN                         NaN
# 3                          264.0                       404.0
# 4                            NaN                         NaN
#
#    soc_15-30cm_mean_0.01_deg
# 0                        NaN
# 1                      139.0
# 2                        NaN
# 3                      177.0
# 4                        NaN
#
# [5 rows x 86 columns]

# %%
# write PCA axis and traits to .csv
finalDf.to_csv(model_out_dir + 'embedding_pca.csv', index=False, header=True , sep=',')

# %% [markdown]
# ### PCA-based simulation of spectra

# %%
# Get the PCA coordinates for the original data
pca_coordinates = pca.transform(x)

# %%
def pca_sim_spectra(pca_object, pca_coordinates):
        pca = pca_object
        simulated_data = np.dot(pca_coordinates, pca.components_) + pca.mean_
        sim = standardizer.inverse_transform(simulated_data)
        return sim

# %%
def pca_sim_coord(pca_coordinates, sel_columns, n_sample):
    # create a empty data frame with as many columns as pca_coordinates and n_sample rows
    #sim_df = pd.DataFrame(np.random.rand(n_sample, pca_coordinates.shape[1]))
    sim_df = pd.DataFrame(np.zeros((n_sample, pca_coordinates.shape[1]), dtype=float))


#fill each column with the mean value of the respective column in pca_coordinates
    for i in range(pca_coordinates.shape[1]):
        sim_df.iloc[:, i] = np.mean(pca_coordinates[:, i])


#for each value in columns, sample the values
    for i in sel_columns:
        # sample an equal interval of the last column of principalDf of length 10
        sample = np.linspace(principalDf.iloc[:, -1].quantile(0.0001), principalDf.iloc[:, -1].quantile(0.9999), num=n_sample)
        sim_df.iloc[:, i] = sample
    return sim_df

# %%
specsim = pca_sim_spectra(pca, pca_sim_coord(pca_coordinates, [1], 20))
# plot all spectra within 1 plot
plt.plot(range(400,2501),specsim.T, color='blue', alpha=1)
plt.ylim(0, 0.55)
plt.show()

# %%
#for each pca_componment, simulate the 20 spectra and write it to a pandas dataframe, where and index tracks the number of the component
for pca_component in range(0, 10):
    specsim = pca_sim_spectra(pca, pca_sim_coord(pca_coordinates, [pca_component], 20))
    specsim = pd.DataFrame(specsim)
    specsim.to_csv(model_out_dir + 'simulated_spectra_pca_comp_' + str(pca_component+1) + '.csv', index=False, header=True , sep=',')

#specsim = pca_sim_spectra(pca, pca_sim_coord(pca_coordinates, [pca_component, 20))

# %%
# open simulated_spectra_pca_comp_1 and plot the 20 spectra
sim = pd.read_csv(model_out_dir + 'simulated_spectra_pca_comp_2.csv')
plt.plot(range(400,2501),sim.T, color='blue', alpha=1)
plt.ylim(0, 0.55)
plt.show()

# %% [markdown]
# ### Check the PCA reconstruction quality

# %%
# Now we can simulate new data based on these PCA coordinates
simulated_data = np.dot(pca_coordinates, pca.components_) + pca.mean_
x_tr = standardizer.inverse_transform(x)
sim_tr = standardizer.inverse_transform(simulated_data)

# select a random integer at the length of the dataset
random_int = random.randint(0, len(x_tr))

plt.plot(x_tr[random_int], label = 'original')
plt.plot(sim_tr[random_int], label = 'simulated')

# add legend
plt.legend()
plt.show()

# %% [markdown]
# # Dimension reduction via variational autoencoder

# %%
def numpyToTensor(x):
    x_train = torch.from_numpy(x).to(device)
    return x_train

# %%
from torch.utils.data import Dataset, DataLoader
class DataBuilder(Dataset):
    def __init__(self, path):
        self.x, self.standardizer, self.meta = load_data(path)
        self.x = numpyToTensor(self.x)
        self.len=self.x.shape[0]
    def __getitem__(self,index):
        return self.x[index]
    def __len__(self):
        return self.len

# %% [markdown]
# ## Implement variational autoencoder architecture and train model

# %%
class Autoencoder(nn.Module):
    def __init__(self, D_in, H1=256, H2=128, H3=64, H4=32, latent_dim=5):
        super(Autoencoder, self).__init__()
        
        # Encoder
        self.linear1 = nn.Linear(D_in, H1)
        self.lin_bn1 = nn.BatchNorm1d(num_features=H1)
        self.linear2 = nn.Linear(H1, H2)
        self.lin_bn2 = nn.BatchNorm1d(num_features=H2)
        self.linear3 = nn.Linear(H2, H3)
        self.lin_bn3 = nn.BatchNorm1d(num_features=H3)
        self.linear4 = nn.Linear(H3, H4)
        self.lin_bn4 = nn.BatchNorm1d(num_features=H4)
        
        # Latent vectors mu and sigma
        self.fc1 = nn.Linear(H4, latent_dim)
        self.bn1 = nn.BatchNorm1d(num_features=latent_dim)
        self.fc21 = nn.Linear(latent_dim, latent_dim)
        self.fc22 = nn.Linear(latent_dim, latent_dim)

        # Sampling vector
        self.fc3 = nn.Linear(latent_dim, latent_dim)
        self.fc_bn3 = nn.BatchNorm1d(latent_dim)
        self.fc4 = nn.Linear(latent_dim, H4)
        self.fc_bn4 = nn.BatchNorm1d(H4)

        # Decoder
        self.linear5 = nn.Linear(H4, H3)
        self.lin_bn5 = nn.BatchNorm1d(num_features=H3)
        self.linear6 = nn.Linear(H3, H2)
        self.lin_bn6 = nn.BatchNorm1d(num_features=H2)
        self.linear7 = nn.Linear(H2, H1)
        self.lin_bn7 = nn.BatchNorm1d(num_features=H1)
        self.linear8 = nn.Linear(H1, D_in)
        self.lin_bn8 = nn.BatchNorm1d(num_features=D_in)

        self.relu = nn.ReLU()

    def encode(self, x):
        lin1 = self.relu(self.lin_bn1(self.linear1(x)))
        lin2 = self.relu(self.lin_bn2(self.linear2(lin1)))
        lin3 = self.relu(self.lin_bn3(self.linear3(lin2)))
        lin4 = self.relu(self.lin_bn4(self.linear4(lin3)))

        fc1 = self.relu(self.bn1(self.fc1(lin4)))

        r1 = self.fc21(fc1)
        r2 = self.fc22(fc1)

        return r1, r2

    def reparameterize(self, mu, logvar):
        std = logvar.mul(0.5).exp_()
        eps = Variable(std.data.new(std.size()).normal_())
        return eps.mul(std).add_(mu)

    def decode(self, z):
        fc3 = self.relu(self.fc_bn3(self.fc3(z)))
        fc4 = self.relu(self.fc_bn4(self.fc4(fc3)))

        lin5 = self.relu(self.lin_bn5(self.linear5(fc4)))
        lin6 = self.relu(self.lin_bn6(self.linear6(lin5)))
        lin7 = self.relu(self.lin_bn7(self.linear7(lin6)))
        return self.lin_bn8(self.linear8(lin7))

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), z, mu, logvar

# %%
############ Loss functions ##

# class customLoss(nn.Module):
#     def __init__(self):
#         super(customLoss, self).__init__()
#         self.mse_loss = nn.MSELoss(reduction="sum")

#     # x_recon ist der im forward im Model erstellte recon_batch, x ist der originale x Batch, mu ist mu und logvar ist logvar
#     def forward(self, x_recon, x, mu, logvar):
#         loss_MSE = self.mse_loss(x_recon, x)
#         loss_KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

#         return loss_MSE + loss_KLD



# class mseLoss(nn.Module):
#     def __init__(self):
#         super(mseLoss, self).__init__()
#         self.mse_loss = nn.MSELoss(reduction="sum")
#         #self.mse_loss = nn.L1Loss(reduction="sum")

#     # x_recon ist der im forward im Model erstellte recon_batch, x ist der originale x Batch, mu ist mu und logvar ist logvar
#     def forward(self, x_recon, x):
#         loss_MSE = self.mse_loss(x_recon, x)

#         return loss_MSE
    

class mseLoss(nn.Module):
    def __init__(self, alpha=0.5):
        super(mseLoss, self).__init__()
        self.mse_loss = nn.MSELoss(reduction="sum")
        self.cosine_loss = nn.CosineEmbeddingLoss()
        self.alpha = alpha  # This is the weight for the MSE loss

    def forward(self, x_recon, x):
        loss_MSE = self.mse_loss(x_recon, x)
        # CosineEmbeddingLoss expects inputs to be in the shape (batch_size, dim) and a target of size (batch_size) with values 1 or -1
        x_recon = x_recon.view(x_recon.size(0), -1)
        x = x.view(x.size(0), -1)
        target = x.new_ones(x.size(0))  # All target values are 1
        loss_cosine = self.cosine_loss(x_recon, x, target)

        return self.alpha * loss_MSE + (1 - self.alpha) * loss_cosine
    


class KLDLoss(nn.Module):
    def __init__(self):
        super(KLDLoss, self).__init__()

    # x_recon ist der im forward im Model erstellte recon_batch, x ist der originale x Batch, mu ist mu und logvar ist logvar
    def forward(self, mu, logvar):
        loss_KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

        return loss_KLD

# %%
####### Decoupling losses #####

class decouplingLoss(nn.Module):
    def __init__(self):
        super(decouplingLoss, self).__init__()

    def forward(self, mu, logvar):
        # Compute the covariance matrix of the latent variables
        mu_centered = mu - mu.mean(dim=0)
        cov_matrix = mu_centered.t().mm(mu_centered) / mu_centered.size(0)

        # Add the sum of the off-diagonal elements to the loss
        loss_cov = cov_matrix.sum() - torch.diag(cov_matrix).sum()
        return loss_cov

def total_correlation(z, mu, logvar):
    # Flatten z if necessary
    if len(z.size()) > 2:
        z = z.view(z.size(0), -1)

    log_qz = log_density_gaussian(z, mu, logvar)
    log_qz_product = log_qz.sum(1, keepdim=True)
    log_qz_sum = log_qz.sum(0, keepdim=True)
    tc = (log_qz_sum - log_qz_product).mean()
    return tc

def log_density_gaussian(x, mu, logvar):
    c = torch.log(torch.tensor(2. * torch.pi))
    var = torch.exp(logvar)
    log_density = -0.5 * (c + logvar + ((x - mu) ** 2) / var)
    return log_density

# %%
# # takes in a module and applies the specified weight initialization
# def weights_init_uniform_rule(m):
#     classname = m.__class__.__name__
#     # for every Linear layer in a model..
#     if classname.find('Linear') != -1:
#         # get the number of the inputs
#         n = m.in_features
#         y = 1.0/np.sqrt(n)
#         m.weight.data.uniform_(-y, y)
#         m.bias.data.fill_(0)

# %% [markdown]
# # Train

# %%
#### epoch training process #####

def train(epoch, loss_best):
    model.train()
    train_loss = 0

    for batch_idx, data in enumerate(trainloader):
        data = data.to(device)
        optimizer.zero_grad()
        # recon_batch, mu, logvar = model(data)
        recon_batch, z, mu, logvar = model(data)

        # loss = loss_mse(recon_batch, data, mu, logvar)

        loss_kld_ = loss_kld(mu, logvar)
        # print(loss_kld_.item())

        loss_mse_ = loss_mse(recon_batch, data) / recon_batch.shape[0]
        # print(loss_mse_.item())

        # Decoupling Loss (Total Correlation)
        # z = model.sample_latent(mu, logvar)  # Assuming your model has a method to sample from the latent space
        loss_tc_ = total_correlation(z, mu, logvar)
        # print(loss_tc_.item())
        # loss_decouple_ = loss_decouple(mu, logvar)
        # print(loss_decouple_.item())

        loss = loss_kld_ + lambda_* loss_mse_ + loss_tc_/2 #loss_decouple_
        # print(loss.item())

        loss.backward()
        train_loss += loss.item()
        optimizer.step()

        #### log step metrics to wandb ###
        metrics_per_step = {'train_step/train_loss': loss.item()}
        metrics_per_step.update({'train_step/train_loss_mse_': loss_mse_.item()})
        metrics_per_step.update({'train_step/train_loss_kld': loss_kld_.item()})
        metrics_per_step.update({'train_step/train_loss_tc': loss_tc_.item()})
        wandb.log(metrics_per_step) #, step=batch_idx+1

    # safe model if loss is better than before
    loss_epoch = train_loss / len(trainloader)
    train_losses.append(loss_epoch)
    # print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, loss_epoch))

    #### log epoch metrics to wandb ###
    metrics_per_step = {'train_epoch/train_loss': loss_epoch}
    wandb.log(metrics_per_step) #, step=batch_idx+1

    # global loss_best
    if loss_best > loss_epoch:
        #safe model
        torch.save(model.state_dict(), model_out_dir + 'model.pth')
            # restore mode: model.load_state_dict(torch.load(model_out_dir + 'model.pth'))
        # write loss to txt file
        with open(model_out_dir + 'loss.txt', 'w') as f:
            f.write('loss: {}'.format(loss_epoch))
        loss_best = loss_epoch

    if epoch % log_interval == 0:
        print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, loss_epoch))
        with open(model_out_dir + 'losses.csv', 'w', newline='') as f:
            writer = csv.writer(f)
            for loss in train_losses:
                writer.writerow([loss])

# %%
######### Experiment settings ###
epochs = 30000
log_interval = 50

val_losses = []
train_losses = []

global loss_best
loss_best = float(1000000) # loss value for initlization

D_in = x.shape[1] #data_set.x.shape[1]
H1 = 256 #hidden_dim1 (50)
H2 = 128 #hidden_dim2 (12)
H3 = 64
H4 = 32

latent_dim=10

lambda_ = 1 #1e-2
lr = 1e-4

# set the batch size
batch_size_train = 128

if not os.path.exists(model_out_dir):
    os.makedirs(model_out_dir)

# %%
###### model initialization ##

wandb.init(project='Spectra_VAE') ## wandb logging

data_set = DataBuilder(data_path)
trainloader = DataLoader(dataset = data_set, batch_size = batch_size_train, shuffle=True)
evalloadder = DataLoader(dataset = data_set, batch_size = batch_size_train, shuffle=False)

model = Autoencoder(D_in, H1=H1, H2=H2, H3=H3, H4=H4, latent_dim=latent_dim).to(device)
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

loss_kld = KLDLoss()
loss_mse = mseLoss()
loss_decouple = decouplingLoss()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: teja-kattenborn (geosense). Use `wandb login --relogin` to force relogin
# wandb version 0.17.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>/home/tk1112/wandb/run-20240601_192254-rlp0uh4g</code>
# Syncing run <strong><a href='https://wandb.ai/geosense/Spectra_VAE/runs/rlp0uh4g/workspace' target="_blank">smart-disco-56</a></strong> to <a href='https://wandb.ai/geosense/Spectra_VAE' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/geosense/Spectra_VAE' target="_blank">https://wandb.ai/geosense/Spectra_VAE</a>
#  View run at <a href='https://wandb.ai/geosense/Spectra_VAE/runs/rlp0uh4g/workspace' target="_blank">https://wandb.ai/geosense/Spectra_VAE/runs/rlp0uh4g/workspace</a>

# %%
for epoch in range(1, epochs + 1):
    train(epoch, loss_best)
# Out:
# ====> Epoch: 50 Average loss: 551.7690
# ====> Epoch: 100 Average loss: 416.0015
# ====> Epoch: 150 Average loss: 369.6897
# ====> Epoch: 200 Average loss: 364.7809
# ====> Epoch: 250 Average loss: 353.2214
# ====> Epoch: 300 Average loss: 344.0526
# ====> Epoch: 350 Average loss: 348.3147
# ====> Epoch: 400 Average loss: 344.3455
# ====> Epoch: 450 Average loss: 346.2856
# ====> Epoch: 500 Average loss: 343.8921
# ====> Epoch: 550 Average loss: 341.7047
# ====> Epoch: 600 Average loss: 344.4837
# ====> Epoch: 650 Average loss: 345.4339
# ====> Epoch: 700 Average loss: 344.6655
# ====> Epoch: 750 Average loss: 343.0124
# ====> Epoch: 800 Average loss: 339.1423
# ====> Epoch: 850 Average loss: 342.3521
# ====> Epoch: 900 Average loss: 342.3372
# ====> Epoch: 950 Average loss: 344.5801
# ====> Epoch: 1000 Average loss: 341.6764
# ====> Epoch: 1050 Average loss: 339.0199
# ====> Epoch: 1100 Average loss: 342.7278
# ====> Epoch: 1150 Average loss: 341.5894
# ====> Epoch: 1200 Average loss: 343.0042
# ====> Epoch: 1250 Average loss: 340.2037
# ====> Epoch: 1300 Average loss: 343.6103
# ====> Epoch: 1350 Average loss: 340.1822
# ====> Epoch: 1400 Average loss: 341.8349
# ====> Epoch: 1450 Average loss: 341.1072
# ====> Epoch: 1500 Average loss: 337.4978
# ====> Epoch: 1550 Average loss: 340.6866
# ====> Epoch: 1600 Average loss: 340.0557
# ====> Epoch: 1650 Average loss: 343.0064
# ====> Epoch: 1700 Average loss: 343.3430
# ====> Epoch: 1750 Average loss: 341.5213
# ====> Epoch: 1800 Average loss: 337.6325
# ====> Epoch: 1850 Average loss: 344.1215
# ====> Epoch: 1900 Average loss: 342.3929
# ====> Epoch: 1950 Average loss: 340.5841
# ====> Epoch: 2000 Average loss: 340.5519
# ====> Epoch: 2050 Average loss: 342.3351
# ====> Epoch: 2100 Average loss: 343.0968
# ====> Epoch: 2150 Average loss: 342.7971
# ====> Epoch: 2200 Average loss: 342.5419
# ====> Epoch: 2250 Average loss: 343.2033
# ====> Epoch: 2300 Average loss: 344.8115
# ====> Epoch: 2350 Average loss: 343.6150
# ====> Epoch: 2400 Average loss: 344.1363
# ====> Epoch: 2450 Average loss: 341.5355
# ====> Epoch: 2500 Average loss: 338.7400
# ====> Epoch: 2550 Average loss: 341.6028
# ====> Epoch: 2600 Average loss: 344.2636
# ====> Epoch: 2650 Average loss: 343.5398
# ====> Epoch: 2700 Average loss: 337.4685
# ====> Epoch: 2750 Average loss: 342.5905
# ====> Epoch: 2800 Average loss: 340.2166
# ====> Epoch: 2850 Average loss: 337.9068
# ====> Epoch: 2900 Average loss: 338.4217
# ====> Epoch: 2950 Average loss: 340.6460
# ====> Epoch: 3000 Average loss: 341.5807
# ====> Epoch: 3050 Average loss: 343.3753
# ====> Epoch: 3100 Average loss: 342.8499
# ====> Epoch: 3150 Average loss: 343.2076
# ====> Epoch: 3200 Average loss: 341.3769
# ====> Epoch: 3250 Average loss: 339.8145
# ====> Epoch: 3300 Average loss: 338.0891
# ====> Epoch: 3350 Average loss: 340.6241
# ====> Epoch: 3400 Average loss: 344.8472
# ====> Epoch: 3450 Average loss: 342.1501
# ====> Epoch: 3500 Average loss: 339.7363
# ====> Epoch: 3550 Average loss: 343.4107
# ====> Epoch: 3600 Average loss: 342.8237
# ====> Epoch: 3650 Average loss: 345.3563
# ====> Epoch: 3700 Average loss: 344.5188
# ====> Epoch: 3750 Average loss: 337.0565
# ====> Epoch: 3800 Average loss: 339.3424
# ====> Epoch: 3850 Average loss: 340.3639
# ====> Epoch: 3900 Average loss: 339.5954
# ====> Epoch: 3950 Average loss: 340.8124
# ====> Epoch: 4000 Average loss: 340.7814
# ====> Epoch: 4050 Average loss: 340.0029
# ====> Epoch: 4100 Average loss: 337.2634
# ====> Epoch: 4150 Average loss: 340.1413
# ====> Epoch: 4200 Average loss: 344.2922
# ====> Epoch: 4250 Average loss: 339.6201
# ====> Epoch: 4300 Average loss: 340.6194
# ====> Epoch: 4350 Average loss: 341.1366
# ====> Epoch: 4400 Average loss: 341.4824
# ====> Epoch: 4450 Average loss: 339.2064
# ====> Epoch: 4500 Average loss: 338.0171
# ====> Epoch: 4550 Average loss: 341.3045
# ====> Epoch: 4600 Average loss: 341.4911
# ====> Epoch: 4650 Average loss: 337.6045
# ====> Epoch: 4700 Average loss: 338.5069
# ====> Epoch: 4750 Average loss: 341.8517
# ====> Epoch: 4800 Average loss: 338.5262
# ====> Epoch: 4850 Average loss: 340.0345
# ====> Epoch: 4900 Average loss: 335.2793
# ====> Epoch: 4950 Average loss: 341.1725
# ====> Epoch: 5000 Average loss: 340.1498
# ====> Epoch: 5050 Average loss: 339.8721
# ====> Epoch: 5100 Average loss: 339.5116
# ====> Epoch: 5150 Average loss: 336.4972
# ====> Epoch: 5200 Average loss: 341.2399
# ====> Epoch: 5250 Average loss: 340.0569
# ====> Epoch: 5300 Average loss: 342.5052
# ====> Epoch: 5350 Average loss: 346.0192
# ====> Epoch: 5400 Average loss: 339.2360
# ====> Epoch: 5450 Average loss: 337.6659
# ====> Epoch: 5500 Average loss: 337.5071
# ====> Epoch: 5550 Average loss: 336.9483
# ====> Epoch: 5600 Average loss: 341.0448
# ====> Epoch: 5650 Average loss: 339.4095
# ====> Epoch: 5700 Average loss: 340.1462
# ====> Epoch: 5750 Average loss: 342.5377
# ====> Epoch: 5800 Average loss: 342.9868
# ====> Epoch: 5850 Average loss: 343.5682
# ====> Epoch: 5900 Average loss: 340.6397
# ====> Epoch: 5950 Average loss: 341.2039
# ====> Epoch: 6000 Average loss: 338.4499
# ====> Epoch: 6050 Average loss: 339.8115
# ====> Epoch: 6100 Average loss: 341.2066
# ====> Epoch: 6150 Average loss: 345.8823
# ====> Epoch: 6200 Average loss: 341.1212
# ====> Epoch: 6250 Average loss: 337.8684
# ====> Epoch: 6300 Average loss: 343.2929
# ====> Epoch: 6350 Average loss: 337.4818
# ====> Epoch: 6400 Average loss: 338.2608
# ====> Epoch: 6450 Average loss: 341.2996
# ====> Epoch: 6500 Average loss: 338.7856
# ====> Epoch: 6550 Average loss: 338.0236
# ====> Epoch: 6600 Average loss: 340.2558
# ====> Epoch: 6650 Average loss: 340.3685
# ====> Epoch: 6700 Average loss: 340.5050
# ====> Epoch: 6750 Average loss: 337.7016
# ====> Epoch: 6800 Average loss: 342.1157
# ====> Epoch: 6850 Average loss: 337.3970
# ====> Epoch: 6900 Average loss: 342.3626
# ====> Epoch: 6950 Average loss: 344.1123
# ====> Epoch: 7000 Average loss: 342.3567
# ====> Epoch: 7050 Average loss: 338.7772
# ====> Epoch: 7100 Average loss: 335.8577
# ====> Epoch: 7150 Average loss: 343.3565
# ====> Epoch: 7200 Average loss: 342.4539
# ====> Epoch: 7250 Average loss: 338.1935
# ====> Epoch: 7300 Average loss: 339.3698
# ====> Epoch: 7350 Average loss: 341.5276
# ====> Epoch: 7400 Average loss: 338.2685
# ====> Epoch: 7450 Average loss: 335.0198
# ====> Epoch: 7500 Average loss: 342.5216
# ====> Epoch: 7550 Average loss: 337.9730
# ====> Epoch: 7600 Average loss: 339.4250
# ====> Epoch: 7650 Average loss: 334.6913
# ====> Epoch: 7700 Average loss: 340.5300
# ====> Epoch: 7750 Average loss: 339.3443
# ====> Epoch: 7800 Average loss: 343.6073
# ====> Epoch: 7850 Average loss: 343.1038
# ====> Epoch: 7900 Average loss: 337.1604
# ====> Epoch: 7950 Average loss: 335.1468
# ====> Epoch: 8000 Average loss: 344.7555
# ====> Epoch: 8050 Average loss: 338.2905
# ====> Epoch: 8100 Average loss: 340.4377
# ====> Epoch: 8150 Average loss: 342.3289
# ====> Epoch: 8200 Average loss: 341.1862
# ====> Epoch: 8250 Average loss: 345.3440
# ====> Epoch: 8300 Average loss: 347.1223
# ====> Epoch: 8350 Average loss: 340.9662
# ====> Epoch: 8400 Average loss: 345.6133
# ====> Epoch: 8450 Average loss: 339.0594
# ====> Epoch: 8500 Average loss: 338.9468
# ====> Epoch: 8550 Average loss: 336.0185
# ====> Epoch: 8600 Average loss: 336.4774
# ====> Epoch: 8650 Average loss: 337.6099
# ====> Epoch: 8700 Average loss: 335.9193
# ====> Epoch: 8750 Average loss: 346.2393
# ====> Epoch: 8800 Average loss: 343.2496
# ====> Epoch: 8850 Average loss: 338.1568
# ====> Epoch: 8900 Average loss: 339.7744
# ====> Epoch: 8950 Average loss: 342.5067
# ====> Epoch: 9000 Average loss: 341.2689
# ====> Epoch: 9050 Average loss: 337.3026
# ====> Epoch: 9100 Average loss: 332.0124
# ====> Epoch: 9150 Average loss: 340.7516
# ====> Epoch: 9200 Average loss: 339.2416
# ====> Epoch: 9250 Average loss: 336.3691
# ====> Epoch: 9300 Average loss: 337.8454
# ====> Epoch: 9350 Average loss: 341.2499
# ====> Epoch: 9400 Average loss: 340.0197
# ====> Epoch: 9450 Average loss: 337.5935
# ====> Epoch: 9500 Average loss: 343.9972
# ====> Epoch: 9550 Average loss: 344.5841
# ====> Epoch: 9600 Average loss: 335.5082
# ====> Epoch: 9650 Average loss: 338.8957
# ====> Epoch: 9700 Average loss: 344.8815
# ====> Epoch: 9750 Average loss: 338.7123
# ====> Epoch: 9800 Average loss: 342.2899
# ====> Epoch: 9850 Average loss: 337.4296
# ====> Epoch: 9900 Average loss: 341.5865
# ====> Epoch: 9950 Average loss: 342.8915
# ====> Epoch: 10000 Average loss: 342.5653
# ====> Epoch: 10050 Average loss: 340.3340
# ====> Epoch: 10100 Average loss: 342.1708
# ====> Epoch: 10150 Average loss: 339.5993
# ====> Epoch: 10200 Average loss: 341.3361
# ====> Epoch: 10250 Average loss: 339.7516
# ====> Epoch: 10300 Average loss: 340.0425
# ====> Epoch: 10350 Average loss: 340.8631
# ====> Epoch: 10400 Average loss: 342.9369
# ====> Epoch: 10450 Average loss: 336.6332
# ====> Epoch: 10500 Average loss: 341.7263
# ====> Epoch: 10550 Average loss: 337.4439
# ====> Epoch: 10600 Average loss: 350.3648
# ====> Epoch: 10650 Average loss: 334.8144
# ====> Epoch: 10700 Average loss: 334.8087
# ====> Epoch: 10750 Average loss: 340.7111
# ====> Epoch: 10800 Average loss: 337.8321
# ====> Epoch: 10850 Average loss: 339.4345
# ====> Epoch: 10900 Average loss: 341.4166
# ====> Epoch: 10950 Average loss: 339.8612
# ====> Epoch: 11000 Average loss: 339.0383
# ====> Epoch: 11050 Average loss: 344.7138
# ====> Epoch: 11100 Average loss: 341.3177
# ====> Epoch: 11150 Average loss: 342.8268
# ====> Epoch: 11200 Average loss: 337.5048
# ====> Epoch: 11250 Average loss: 339.7308
# ====> Epoch: 11300 Average loss: 337.7393
# ====> Epoch: 11350 Average loss: 343.0704
# ====> Epoch: 11400 Average loss: 341.8109
# ====> Epoch: 11450 Average loss: 343.1291
# ====> Epoch: 11500 Average loss: 343.2288
# ====> Epoch: 11550 Average loss: 342.3260
# ====> Epoch: 11600 Average loss: 338.7409
# ====> Epoch: 11650 Average loss: 338.1955
# ====> Epoch: 11700 Average loss: 346.1059
# ====> Epoch: 11750 Average loss: 340.5442
# ====> Epoch: 11800 Average loss: 345.1340
# ====> Epoch: 11850 Average loss: 338.9403
# ====> Epoch: 11900 Average loss: 335.3587
# ====> Epoch: 11950 Average loss: 337.3887
# ====> Epoch: 12000 Average loss: 339.9216
# ====> Epoch: 12050 Average loss: 340.7677
# ====> Epoch: 12100 Average loss: 341.0296
# ====> Epoch: 12150 Average loss: 338.0273
# ====> Epoch: 12200 Average loss: 335.9899
# ====> Epoch: 12250 Average loss: 338.1230
# ====> Epoch: 12300 Average loss: 345.7906
# ====> Epoch: 12350 Average loss: 337.1535
# ====> Epoch: 12400 Average loss: 338.6994
# ====> Epoch: 12450 Average loss: 339.8236
# ====> Epoch: 12500 Average loss: 337.1728
# ====> Epoch: 12550 Average loss: 340.2159
# ====> Epoch: 12600 Average loss: 335.4472
# ====> Epoch: 12650 Average loss: 339.0314
# ====> Epoch: 12700 Average loss: 339.5803
# ====> Epoch: 12750 Average loss: 337.1270
# ====> Epoch: 12800 Average loss: 338.7851
# ====> Epoch: 12850 Average loss: 340.8209
# ====> Epoch: 12900 Average loss: 339.1071
# ====> Epoch: 12950 Average loss: 338.5567
# ====> Epoch: 13000 Average loss: 337.6485
# ====> Epoch: 13050 Average loss: 339.3928
# ====> Epoch: 13100 Average loss: 341.4241
# ====> Epoch: 13150 Average loss: 344.5819
# ====> Epoch: 13200 Average loss: 337.1697
# ====> Epoch: 13250 Average loss: 341.1234
# ====> Epoch: 13300 Average loss: 338.3250
# ====> Epoch: 13350 Average loss: 340.0816
# ====> Epoch: 13400 Average loss: 337.8172
# ====> Epoch: 13450 Average loss: 340.2495
# ====> Epoch: 13500 Average loss: 344.1557
# ====> Epoch: 13550 Average loss: 339.0046
# ====> Epoch: 13600 Average loss: 339.3442
# ====> Epoch: 13650 Average loss: 342.0867
# ====> Epoch: 13700 Average loss: 338.1436
# ====> Epoch: 13750 Average loss: 339.6922
# ====> Epoch: 13800 Average loss: 340.8299
# ====> Epoch: 13850 Average loss: 341.0444
# ====> Epoch: 13900 Average loss: 340.9935
# ====> Epoch: 13950 Average loss: 338.9110
# ====> Epoch: 14000 Average loss: 345.7444
# ====> Epoch: 14050 Average loss: 336.7900
# ====> Epoch: 14100 Average loss: 338.9472
# ====> Epoch: 14150 Average loss: 332.1399
# ====> Epoch: 14200 Average loss: 342.5257
# ====> Epoch: 14250 Average loss: 338.8926
# ====> Epoch: 14300 Average loss: 335.5282
# ====> Epoch: 14350 Average loss: 336.7163
# ====> Epoch: 14400 Average loss: 342.6508
# ====> Epoch: 14450 Average loss: 337.4765
# ====> Epoch: 14500 Average loss: 343.1604
# ====> Epoch: 14550 Average loss: 340.1992
# ====> Epoch: 14600 Average loss: 337.5037
# ====> Epoch: 14650 Average loss: 338.5458
# ====> Epoch: 14700 Average loss: 334.8725
# ====> Epoch: 14750 Average loss: 339.8591
# ====> Epoch: 14800 Average loss: 340.7241
# ====> Epoch: 14850 Average loss: 338.4635
# ====> Epoch: 14900 Average loss: 340.1193
# ====> Epoch: 14950 Average loss: 341.2158
# ====> Epoch: 15000 Average loss: 340.4938
# ====> Epoch: 15050 Average loss: 337.2366
# ====> Epoch: 15100 Average loss: 338.0105
# ====> Epoch: 15150 Average loss: 342.4837
# ====> Epoch: 15200 Average loss: 339.9771
# ====> Epoch: 15250 Average loss: 337.9404
# ====> Epoch: 15300 Average loss: 336.0131
# ====> Epoch: 15350 Average loss: 339.2609
# ====> Epoch: 15400 Average loss: 340.4007
# ====> Epoch: 15450 Average loss: 341.8850
# ====> Epoch: 15500 Average loss: 338.0672
# ====> Epoch: 15550 Average loss: 337.5123
# ====> Epoch: 15600 Average loss: 338.4030
# ====> Epoch: 15650 Average loss: 340.9510
# ====> Epoch: 15700 Average loss: 339.1184
# ====> Epoch: 15750 Average loss: 341.1266
# ====> Epoch: 15800 Average loss: 337.6835
# ====> Epoch: 15850 Average loss: 340.0796
# ====> Epoch: 15900 Average loss: 337.1416
# ====> Epoch: 15950 Average loss: 339.2320
# ====> Epoch: 16000 Average loss: 340.9679
# ====> Epoch: 16050 Average loss: 336.5950
# ====> Epoch: 16100 Average loss: 341.1515
# ====> Epoch: 16150 Average loss: 345.2640
# ====> Epoch: 16200 Average loss: 341.2340
# ====> Epoch: 16250 Average loss: 337.5792
# ====> Epoch: 16300 Average loss: 335.0719
# ====> Epoch: 16350 Average loss: 344.0136
# ====> Epoch: 16400 Average loss: 340.3690
# ====> Epoch: 16450 Average loss: 339.8364
# ====> Epoch: 16500 Average loss: 338.8842
# ====> Epoch: 16550 Average loss: 341.1052
# ====> Epoch: 16600 Average loss: 341.1336
# ====> Epoch: 16650 Average loss: 339.1830
# ====> Epoch: 16700 Average loss: 338.7624
# ====> Epoch: 16750 Average loss: 335.0031
# ====> Epoch: 16800 Average loss: 341.0274
# ====> Epoch: 16850 Average loss: 342.1425
# ====> Epoch: 16900 Average loss: 340.3136
# ====> Epoch: 16950 Average loss: 341.2754
# ====> Epoch: 17000 Average loss: 335.1374
# ====> Epoch: 17050 Average loss: 342.7097
# ====> Epoch: 17100 Average loss: 340.7376
# ====> Epoch: 17150 Average loss: 339.9907
# ====> Epoch: 17200 Average loss: 345.1365
# ====> Epoch: 17250 Average loss: 342.8757
# ====> Epoch: 17300 Average loss: 344.2691
# ====> Epoch: 17350 Average loss: 343.1550
# ====> Epoch: 17400 Average loss: 338.8291
# ====> Epoch: 17450 Average loss: 338.9174
# ====> Epoch: 17500 Average loss: 345.3164
# ====> Epoch: 17550 Average loss: 342.2884
# ====> Epoch: 17600 Average loss: 340.6141
# ====> Epoch: 17650 Average loss: 341.7661
# ====> Epoch: 17700 Average loss: 339.7663
# ====> Epoch: 17750 Average loss: 334.8132
# ====> Epoch: 17800 Average loss: 338.3853
# ====> Epoch: 17850 Average loss: 339.8762
# ====> Epoch: 17900 Average loss: 343.1978
# ====> Epoch: 17950 Average loss: 337.1367
# ====> Epoch: 18000 Average loss: 339.0926
# ====> Epoch: 18050 Average loss: 338.1736
# ====> Epoch: 18100 Average loss: 340.0889
# ====> Epoch: 18150 Average loss: 338.3736
# ====> Epoch: 18200 Average loss: 340.0010
# ====> Epoch: 18250 Average loss: 341.0692
# ====> Epoch: 18300 Average loss: 339.0324
# ====> Epoch: 18350 Average loss: 334.3617
# ====> Epoch: 18400 Average loss: 342.9752
# ====> Epoch: 18450 Average loss: 337.1968
# ====> Epoch: 18500 Average loss: 342.0070
# ====> Epoch: 18550 Average loss: 339.7535
# ====> Epoch: 18600 Average loss: 336.0741
# ====> Epoch: 18650 Average loss: 335.4990
# ====> Epoch: 18700 Average loss: 340.5589
# ====> Epoch: 18750 Average loss: 338.6581
# ====> Epoch: 18800 Average loss: 341.7374
# ====> Epoch: 18850 Average loss: 341.7047
# ====> Epoch: 18900 Average loss: 339.8668
# ====> Epoch: 18950 Average loss: 341.0430
# ====> Epoch: 19000 Average loss: 340.6108
# ====> Epoch: 19050 Average loss: 338.0146
# ====> Epoch: 19100 Average loss: 339.9174
# ====> Epoch: 19150 Average loss: 343.8952
# ====> Epoch: 19200 Average loss: 337.1127
# ====> Epoch: 19250 Average loss: 337.2198
# ====> Epoch: 19300 Average loss: 341.0997
# ====> Epoch: 19350 Average loss: 337.8945
# ====> Epoch: 19400 Average loss: 336.1750
# ====> Epoch: 19450 Average loss: 338.7568
# ====> Epoch: 19500 Average loss: 342.5274
# ====> Epoch: 19550 Average loss: 342.2561
# ====> Epoch: 19600 Average loss: 343.5739
# ====> Epoch: 19650 Average loss: 343.9169
# ====> Epoch: 19700 Average loss: 342.8429
# ====> Epoch: 19750 Average loss: 337.0742
# ====> Epoch: 19800 Average loss: 342.8461
# ====> Epoch: 19850 Average loss: 336.4802
# ====> Epoch: 19900 Average loss: 342.0403
# ====> Epoch: 19950 Average loss: 344.4111
# ====> Epoch: 20000 Average loss: 342.1760
# ====> Epoch: 20050 Average loss: 335.1062
# ====> Epoch: 20100 Average loss: 340.9661
# ====> Epoch: 20150 Average loss: 337.9460
# ====> Epoch: 20200 Average loss: 339.6087
# ====> Epoch: 20250 Average loss: 340.1997
# ====> Epoch: 20300 Average loss: 335.7782
# ====> Epoch: 20350 Average loss: 338.5947
# ====> Epoch: 20400 Average loss: 335.3287
# ====> Epoch: 20450 Average loss: 337.0037
# ====> Epoch: 20500 Average loss: 336.4559
# ====> Epoch: 20550 Average loss: 334.5288
# ====> Epoch: 20600 Average loss: 336.6632
# ====> Epoch: 20650 Average loss: 339.9771
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[87], line 2
#       1 for epoch in range(1, epochs + 1):
# ----> 2     train(epoch, loss_best)
#
# Cell In[84], line 31, in train(epoch, loss_best)
#      28 loss = loss_kld_ + lambda_* loss_mse_ + loss_tc_/2 #loss_decouple_
#      29 # print(loss.item())
# ---> 31 loss.backward()
#      32 train_loss += loss.item()
#      33 optimizer.step()
#
# File ~/miniconda3/envs/sdiv_spectra/lib/python3.10/site-packages/torch/_tensor.py:525, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     515 if has_torch_function_unary(self):
#     516     return handle_torch_function(
#     517         Tensor.backward,
#     518         (self,),
#    (...)
#     523         inputs=inputs,
#     524     )
# --> 525 torch.autograd.backward(
#     526     self, gradient, retain_graph, create_graph, inputs=inputs
#     527 )
#
# File ~/miniconda3/envs/sdiv_spectra/lib/python3.10/site-packages/torch/autograd/__init__.py:267, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     262     retain_graph = create_graph
#     264 # The reason we repeat the same comment below is that
#     265 # some Python versions print out the first line of a multi-line function
#     266 # calls in the traceback and some print out the last line
# --> 267 _engine_run_backward(
#     268     tensors,
#     269     grad_tensors_,
#     270     retain_graph,
#     271     create_graph,
#     272     inputs,
#     273     allow_unreachable=True,
#     274     accumulate_grad=True,
#     275 )
#
# File ~/miniconda3/envs/sdiv_spectra/lib/python3.10/site-packages/torch/autograd/graph.py:744, in _engine_run_backward(t_outputs, *args, **kwargs)
#     742     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743 try:
# --> 744     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745         t_outputs, *args, **kwargs
#     746     )  # Calls into the C++ engine to run the backward pass
#     747 finally:
#     748     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # Evaluate the autoencoder

# %%
model.load_state_dict(torch.load(model_out_dir + 'model.pth'))
# Out:
# <All keys matched successfully>

# %%
#standardizer = trainloader.dataset.standardizer

# %%
recon_batches = []
data_batches = []
mu_batches = []
with torch.no_grad():
    for i, data in enumerate(evalloadder):
        recon_batch, z, mu, logvar = model(data)
        data = data.to(device)
        mu_batches.append(mu)
        data_batches.append(data)
        recon_batches.append(recon_batch)

recon = torch.cat((recon_batches), dim = 0)
data = torch.cat((data_batches), dim = 0)
mu = torch.cat((mu_batches), dim = 0)

# %%
standardized_recon = standardizer.inverse_transform(recon.cpu().numpy())
standardized_data = standardizer.inverse_transform(data.cpu().numpy())
print("recon shape", standardized_recon.shape)
print("data shape", standardized_data.shape)
print("mu shape", mu.shape)
# Out:
# recon shape (5883, 2101)
# data shape (5883, 2101)
# mu shape torch.Size([5883, 10])

# %%
# select those column names that represent a value between 400 and 2500
spectracols = [col for col in df.columns if col.isdigit() and 400 <= int(col) <= 2500]
# convert the list of str to an int vector
spectraindex = [int(col) for col in spectracols]

# %%
# Get the number of rows
num_rows = data.shape[0]

# Sample an index value within the number of rows
index = random.randint(0, num_rows-1)
plt.plot(spectraindex, standardized_recon[index], label='Reconstructed')
plt.plot(spectraindex, standardized_data[index], label='Original')
plt.ylim(0, 1)
plt.legend(loc='upper left')  # Add a legend
plt.show()

# %% [markdown]
# ## Load and apply new data
# ... to be prepared

# %%
#data_set2=DataBuilder(DATA_PATH)
#inferenceloader=DataLoader(dataset=data_set2,batch_size=1)

# %%
#with torch.no_grad():
#    for i, data in enumerate(inferenceloader):
#        data_inf = data.to(device)
#        recon_batch, mu, logvar = model(data_inf)

# what about the standardizer?

# %% [markdown]
# ## Apply the autoencoder to (heuristic) encodings

# %%
# apply the decoder of the variaitonal autoencoder to some heuristic latent space values
# and plot the resulting spectra
model.load_state_dict(torch.load(model_out_dir + 'model.pth'))
model.eval()
with torch.no_grad():
    z = torch.tensor([[0.53, 0.28, 1.123, 5.28, 8.123]]).to(device)
    sample = model.decode(z).cpu()
    sample = sample.numpy()
    sample = standardizer.inverse_transform(sample)
    plt.plot(spectraindex, sample[0], label = 'sample')
    plt.legend(loc = 'upper right')
    plt.ylim(0, 1)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[194], line 7
#       5 with torch.no_grad():
#       6     z = torch.tensor([[0.53, 0.28, 1.123, 5.28, 8.123]]).to(device)
# ----> 7     sample = model.decode(z).cpu()
#       8     sample = sample.numpy()
#       9     sample = standardizer.inverse_transform(sample)
#
# Cell In[38], line 58, in Autoencoder.decode(self, z)
#      57 def decode(self, z):
# ---> 58     fc3 = self.relu(self.fc_bn3(self.fc3(z)))
#      59     fc4 = self.relu(self.fc_bn4(self.fc4(fc3)))
#      61     lin5 = self.relu(self.lin_bn5(self.linear5(fc4)))
#
# File ~/miniconda3/envs/sdiv_spectra/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/sdiv_spectra/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/envs/sdiv_spectra/lib/python3.10/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x5 and 10x10)

# %% [markdown]
# # Get Embeddings

# %%
# write emebddings to csv
#numpy_array = mu_result.numpy()

#np.savetxt(model_out_dir + 'embedding_train.csv', numpy_array, delimiter=',')

# write embeddings and traits to .csv
embeddings = pd.DataFrame(mu.cpu().numpy())
finalDf_vae = pd.concat([embeddings, pd.DataFrame(df_meta)], axis = 1)
finalDf_vae.to_csv(model_out_dir + 'embedding_vae.csv', index=False, header=True , sep=',')

# %%
finalDf_vae.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000903 -0.001826  0.002101  0.003549 -0.727904  0.002134 -0.003842
# 1  0.002611 -0.000505 -0.004746  0.002314  0.578273  0.002708 -0.000856
# 2  0.004299  0.001609 -0.007067  0.007711  1.450862  0.006648 -0.001287
# 3 -0.000771 -0.002618  0.004368  0.000739 -1.305456  0.000523 -0.002286
# 4 -0.000308 -0.002891  0.003455  0.000632 -0.965193  0.000498 -0.002061
#
#           7         8         9  ...      bio_1     bio_12  bio_13-14  \
# 0 -1.419147 -0.002329  0.002047  ...  10.275092  780.93780  25.266666
# 1 -0.699511 -0.004655  0.001941  ...  10.163222  768.79114  26.782223
# 2 -1.229333 -0.007639  0.002471  ...  10.507500  762.36444  24.244444
# 3 -0.707284  0.000268  0.000623  ...  10.289963  787.43110  23.120000
# 4 -0.713826 -0.000507  0.001074  ...  10.507500  762.36444  24.244444
#
#       bio_15      bio_4      bio_7 clay_15-30cm_mean_0.01_deg  \
# 0  12.621699  546.30566  22.200000                        NaN
# 1  13.121497  573.76760  23.498667                      215.0
# 2  11.929838  563.06670  22.489779                        NaN
# 3  11.446590  551.49225  22.370667                      231.0
# 4  11.929838  563.06670  22.489779                        NaN
#
#   nitrogen_15-30cm_mean_0.01_deg  sand_15-30cm_mean_0.01_deg  \
# 0                            NaN                         NaN
# 1                          144.0                       230.0
# 2                            NaN                         NaN
# 3                          264.0                       404.0
# 4                            NaN                         NaN
#
#    soc_15-30cm_mean_0.01_deg
# 0                        NaN
# 1                      139.0
# 2                        NaN
# 3                      177.0
# 4                        NaN
#
# [5 rows x 86 columns]

# %% [markdown]
# # Basic plotting of the dimension reduction

# %% [markdown]
# ## Plot Embeddings of PCA

# %% [markdown]
# ### continuous variable

# %%
from sklearn.preprocessing import LabelEncoder

# Data for three-dimensional scattered points
variable = 'LAI_m2_m2'

filteredDf = finalDf[finalDf[variable] != -99]

metatype = filteredDf['LAI_m2_m2'].values

fig = plt.figure(figsize=(10, 8))  # Adjust the width and height as needed
ax = fig.add_subplot(111)

zdata = filteredDf.iloc[:,0].values
xdata = filteredDf.iloc[:,1].values
sc = ax.scatter(xdata, zdata, c=metatype, cmap='viridis')

cbar = plt.colorbar(sc)
cbar.set_label('LAI_m2_m2', rotation=270)

plt.show()

# %% [markdown]
# ## Plot embeddings of autoencoder

# %% [markdown]
# ### categorical variable

# %% [markdown]
# ### continuous variable

# %%
# Data for three-dimensional scattered points
# Data for three-dimensional scattered points

# Assuming finalDf is your DataFrame
#filteredDf = finalDf[(finalDf != -99).all(axis=1)]
#filteredmu_result = mu_result[(finalDf != -99).all(axis=1)]

variable = 'LAI_m2_m2'

filteredDf = finalDf[finalDf[variable] != -99]
filteredmu_result = mu[finalDf[variable] != -99]

metatype = filteredDf[variable].values

fig = plt.figure(figsize=(10, 8))  # Adjust the width and height as needed
ax = fig.add_subplot(111)

ydata = filteredmu_result[:,1].cpu().numpy()
xdata = filteredmu_result[:,2].cpu().numpy()
sc = ax.scatter(xdata, ydata, c=metatype, cmap='viridis');

cbar = plt.colorbar(sc)
cbar.set_label('LAI_m2_m2', rotation=270)

plt.show()

# %% [markdown]
# ## trash bin
